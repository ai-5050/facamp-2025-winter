# %% [markdown]
# *Copyright 2025 Jaeyoung Chun / Winning Twelve*
#
# You may not make copies of this and use or distribute it for any purpose.

# %% [markdown]
# # Drawing

# %% [markdown]
# How can we draw a pitch like below?

# %% [markdown]
# <img src="./img/pitch.png" width="480"/>

# %% [markdown]
# You need to install a new package called `matplotlib` to draw rectangles, circles, and etc.

# %% [markdown]
# Run the following command from the Terminal App or Anaconda Prompt:
#
# ```
# conda activate facamp
# conda install matplotlib
# ```
#
# Once installed, come back to Jupyter Lab.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# You use `as` when you want to shorten a long name.
#
# e.g.
# - Good Game -> gg
# - League of Legends -> lol
# - Laugh Out Loud -> lol

# %% [markdown]
# ## Template

# %%
fig, ax = plt.subplots()

# do something here!

plt.show()

# %% [markdown]
# ## Point

# %%
fig, ax = plt.subplots()

ax.scatter(0.5, 0.4)

plt.show()

# %% [markdown]
# ## Grid

# %%
fig, ax = plt.subplots()

ax.grid()

plt.show()

# %% [markdown]
# ## Line

# %%
fig, ax = plt.subplots()

# x1, x2, y1, y2
ax.plot([0.2, 0.6], [0.3, 0.5])

ax.grid()

plt.show()

# %% [markdown]
# ## Rectangle

# %%
from matplotlib.patches import Rectangle

# %% [markdown]
# ### Filled

# %%
fig, ax = plt.subplots()

# (x, y), width, height
my_rectangle = Rectangle((0.2, 0.2), 0.6, 0.4)
 
ax.add_patch(my_rectangle)

plt.show()

# %% [markdown]
# ### Transparent

# %%
fig, ax = plt.subplots()

my_rectangle = Rectangle((0.2, 0.2), 0.6, 0.4, fill=False)
 
ax.add_patch(my_rectangle)

plt.show()

# %% [markdown]
# ## Circle

# %% [markdown]
# ### Filled

# %%
fig, ax = plt.subplots()
ax.set_aspect(1)

# (x, y), radius
my_circle = plt.Circle((0.5, 0.5), 0.2)
 
ax.add_patch(my_circle)

plt.show()

# %% [markdown]
# ### Transparent

# %%
fig, ax = plt.subplots()
ax.set_aspect(1)

my_circle = plt.Circle((0.5, 0.5), 0.2, fill=False)
 
ax.add_patch(my_circle)

plt.show()

# %% [markdown]
# ## Arc

# %%
from matplotlib.patches import Arc

# %% [markdown]
# The arc is drawn in the counterclockwise direction.

# %%
fig, ax = plt.subplots()
ax.set_aspect(1)

my_arc = Arc(
    (0.5, 0.5),
    height=0.4, width=0.4,
    angle=0,
    theta1=0, theta2=180,
    color="red"
)

ax.add_patch(my_arc)
ax.grid()

plt.show()

# %% [markdown]
# `angle` sets a starting point.

# %%
fig, ax = plt.subplots()
ax.set_aspect(1)

my_arc = Arc(
    (0.5, 0.5),
    height=0.4, width=0.4,
    angle=45,
    theta1=0, theta2=180,
    color="red"
)

ax.add_patch(my_arc)

ax.grid()

plt.show()
