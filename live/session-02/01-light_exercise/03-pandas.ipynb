# %% [markdown]
# *Copyright 2025 Jaeyoung Chun / Winning Twelve*
#
# You may not make copies of this and use or distribute it for any purpose.

# %% [markdown]
# # Pandas

# %% [markdown]
# ## Import Library

# %%
import pandas as pd

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv("./data/players.csv", sep=",")

# %%
df
# Out:
#              Name Position        ClubName  Age  Height  Weight  Overall  \
# 0        M. Noble       CM        West Ham   32  1,80 m      76       76
# 1     R. Stearman       CB  Sheffield Utd.   32  1,91 m      76       69
# 2       G. Hanley       CB         Norwich   27  1,88 m      81       70
# 3     P. Jagielka       CB  Sheffield Utd.   37  1,80 m      87       76
# 4     A. Townsend       RW  Crystal Palace   28  1,81 m      73       78
# ..            ...      ...             ...  ...     ...     ...      ...
# 396   V. Lindelöf       CB         Man Utd   25  1,87 m      80       81
# 397     O. Nyland       GK     Aston Villa   29  1,92 m      90       72
# 398     R. Mahrez       RW        Man City   28  1,79 m      67       84
# 399  S. Armstrong       CM     Southampton   27  1,83 m      75       75
# 400     E. Capoue      CDM         Watford   31  1,89 m      87       80
#
#      Potential  FIFAMarketValue  FIFAWage   Foot  WeakFoot  SkillMoves  \
# ...

# %% [markdown]
# ## Select

# %% [markdown]
# ### Column

# %%
df.Name
# Out:
# 0          M. Noble
# 1       R. Stearman
# 2         G. Hanley
# 3       P. Jagielka
# 4       A. Townsend
#            ...
# 396     V. Lindelöf
# 397       O. Nyland
# 398       R. Mahrez
# 399    S. Armstrong
# 400       E. Capoue
# Name: Name, Length: 401, dtype: object

# %% [markdown]
# ### Row

# %%
df.loc[123]
# Out:
# Name                    H. Son
# Position                    LW
# ClubName                 Spurs
# Age                         27
# Height                  1,84 m
# Weight                      78
# Overall                     87
# Potential                   88
# FIFAMarketValue       60000000
# FIFAWage                185000
# Foot                     Right
# WeakFoot                     5
# SkillMoves                   4
# BodyType                  Lean
# MainPositionStatus        86.0
# MarketValue           80000000
# Name: 123, dtype: object

# %% [markdown]
# ## Search

# %%
df.Age > 35
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 396    False
# 397    False
# 398    False
# 399    False
# 400    False
# Name: Age, Length: 401, dtype: bool

# %%
df[ df.Age > 35 ]
# Out:
#                 Name Position        ClubName  Age  Height  Weight  Overall  \
# 3        P. Jagielka       CB  Sheffield Utd.   37  1,80 m      87       76
# 33   M. Stekelenburg       GK         Everton   37  1,97 m      92       73
# 59      W. Caballero       GK         Chelsea   38  1,86 m      81       75
# 84          L. Grant       GK         Man Utd   36  1,93 m      83       72
# 187        G. Murray       ST        Brighton   36  1,86 m      80       77
# 197      A. Lonergan       GK       Liverpool   36  1,93 m      87       65
# 199         C. Bravo       GK        Man City   36  1,84 m      80       77
# 231            Gomes       GK         Watford   38  1,91 m      95       76
# 294        B. Foster       GK         Watford   36  1,93 m      90       80
# 354         A. Boruc       GK     Bournemouth   39  1,93 m      87       75
#
#      Potential  FIFAMarketValue  FIFAWage   Foot  WeakFoot  SkillMoves  \
# ...

# %% [markdown]
# ## Statistics

# %% [markdown]
# ### Sum

# %%
df.Age.sum()
# Out:
# 10678

# %% [markdown]
# ### Average

# %%
df.Age.mean()
# Out:
# 26.628428927680797

# %% [markdown]
# ### Descriptive Statistics

# %%
df.Age.describe()
# Out:
# count    401.000000
# mean      26.628429
# std        4.195127
# min       18.000000
# 25%       23.000000
# 50%       27.000000
# 75%       30.000000
# max       39.000000
# Name: Age, dtype: float64

# %% [markdown]
# ## Sort

# %% [markdown]
# Player with highest market value

# %%
df.sort_values(by="FIFAMarketValue", ascending=False)
# Out:
#                 Name Position   ClubName  Age  Height  Weight  Overall  \
# 235     K. de Bruyne      CAM   Man City   28  1,81 m      70       91
# 108      V. van Dijk       CB  Liverpool   28  1,93 m      92       90
# 81       R. Sterling       LW   Man City   24  1,70 m      69       88
# 313         P. Pogba       CM    Man Utd   26  1,91 m      84       88
# 280       C. Eriksen      CAM      Spurs   27  1,82 m      76       88
# ..               ...      ...        ...  ...     ...     ...      ...
# 261        D. Martin       GK   West Ham   33  1,88 m      86       66
# 173        J. Sterry       RB  Newcastle   23  1,80 m      76       61
# 372  T. Dele-Bashiru       CM    Watford   20  1,79 m      68       57
# 10        A. Pereira      CAM    Man Utd   23  1,78 m      73       58
# 197      A. Lonergan       GK  Liverpool   36  1,93 m      87       65
#
#      Potential  FIFAMarketValue  FIFAWage   Foot  WeakFoot  SkillMoves  \
# ...

# %% [markdown]
# ## Group

# %% [markdown]
# Average wage per club

# %%
df.groupby("ClubName").FIFAWage.mean()
# Out:
# ClubName
# Arsenal            73428.571429
# Aston Villa        35250.000000
# Bournemouth        42809.523810
# Brighton           36590.909091
# Burnley            40944.444444
# Chelsea            91045.454545
# Crystal Palace     43611.111111
# Everton            60450.000000
# Leicester          48050.000000
# Liverpool         114352.941176
# Man City          171500.000000
# Man Utd            91550.000000
# Newcastle          32086.956522
# Norwich            30800.000000
# Sheffield Utd.     22181.818182
# Southampton        36888.888889
# Spurs             103312.500000
# Watford            49444.444444
# West Ham           67523.809524
# Wolves             44933.333333
# Name: FIFAWage, dtype: float64

# %% [markdown]
# ## Group and Sort

# %%
df.groupby("ClubName").FIFAWage.mean().sort_values(ascending=False)
# Out:
# ClubName
# Man City          171500.000000
# Liverpool         114352.941176
# Spurs             103312.500000
# Man Utd            91550.000000
# Chelsea            91045.454545
# Arsenal            73428.571429
# West Ham           67523.809524
# Everton            60450.000000
# Watford            49444.444444
# Leicester          48050.000000
# Wolves             44933.333333
# Crystal Palace     43611.111111
# Bournemouth        42809.523810
# Burnley            40944.444444
# Southampton        36888.888889
# Brighton           36590.909091
# Aston Villa        35250.000000
# Newcastle          32086.956522
# Norwich            30800.000000
# Sheffield Utd.     22181.818182
# Name: FIFAWage, dtype: float64

# %% [markdown]
# ## Sample

# %%
df.sample(5)
# Out:
#                  Name Position        ClubName  Age  Height  Weight  Overall  \
# 384         C. Basham       CB  Sheffield Utd.   31  1,90 m      80       73
# 26         J. Schlupp       LM  Crystal Palace   26  1,78 m      72       74
# 31        D. Stephens       CM        Brighton   29  1,85 m      78       76
# 293           D. Ward       GK       Leicester   26  1,91 m      88       73
# 61   K. Walker-Peters       RB           Spurs   22  1,73 m      64       74
#
#      Potential  FIFAMarketValue  FIFAWage   Foot  WeakFoot  SkillMoves  \
# 384         73          3200000     25000  Right         2           2
# 26          75          6500000     43000   Left         2           3
# 31          76          7000000     44000  Right         3           3
# 293         74          3300000     39000  Right         3           1
# 61          80          7000000     49000  Right         4           3
#
#     BodyType  MainPositionStatus  MarketValue
# ...

# %%
df2 = df.sample(5)

# %%
df2
# Out:
#            Name Position     ClubName  Age  Height  Weight  Overall  \
# 281    C. Adams       ST  Southampton   23  1,79 m      66       74
# 333  R. Barkley       CM      Chelsea   25  1,85 m      87       79
# 193    P. Foden       CM     Man City   19  1,71 m      69       76
# 109   A. Tettey      CDM      Norwich   33  1,81 m      68       71
# 338    R. Saïss      CDM       Wolves   29  1,88 m      84       77
#
#      Potential  FIFAMarketValue  FIFAWage   Foot  WeakFoot  SkillMoves  \
# 281         81          8000000     41000  Right         4           3
# 333         82         16000000     98000  Right         5           4
# 193         90         16500000     52000   Left         3           4
# 109         71          1200000     25000  Right         2           2
# 338         77          7500000     68000   Left         3           3
#
#     BodyType  MainPositionStatus  MarketValue
# 281   Stocky                72.0     12000000
# ...

# %% [markdown]
# ## Iteration

# %%
for row in df2.itertuples():
    print(row)
# Out:
# Pandas(Index=281, Name='C. Adams', Position='ST', ClubName='Southampton', Age=23, Height='1,79 m', Weight=66, Overall=74, Potential=81, FIFAMarketValue=8000000, FIFAWage=41000, Foot='Right', WeakFoot=4, SkillMoves=3, BodyType='Stocky', MainPositionStatus=72.0, MarketValue=12000000)
# Pandas(Index=333, Name='R. Barkley', Position='CM', ClubName='Chelsea', Age=25, Height='1,85 m', Weight=87, Overall=79, Potential=82, FIFAMarketValue=16000000, FIFAWage=98000, Foot='Right', WeakFoot=5, SkillMoves=4, BodyType='Normal', MainPositionStatus=77.0, MarketValue=30000000)
# Pandas(Index=193, Name='P. Foden', Position='CM', ClubName='Man City', Age=19, Height='1,71 m', Weight=69, Overall=76, Potential=90, FIFAMarketValue=16500000, FIFAWage=52000, Foot='Left', WeakFoot=3, SkillMoves=4, BodyType='Lean', MainPositionStatus=73.0, MarketValue=30000000)
# ...

# %%
for row in df2.itertuples():
    print(2024 - row.Age)
# Out:
# 2001
# 1999
# 2005
# 1991
# 1995

# %% [markdown]
# ## Apply

# %%
df2.Age.apply(lambda x: x)
# Out:
# 281    23
# 333    25
# 193    19
# 109    33
# 338    29
# Name: Age, dtype: int64

# %%
df2.Age.apply(lambda x: 2024 - x)
# Out:
# 281    2001
# 333    1999
# 193    2005
# 109    1991
# 338    1995
# Name: Age, dtype: int64

# %%
df2["YearBorn"] = df2.Age.apply(lambda x: 2024 - x)

# %%
df2
# Out:
#            Name Position     ClubName  Age  Height  Weight  Overall  \
# 281    C. Adams       ST  Southampton   23  1,79 m      66       74
# 333  R. Barkley       CM      Chelsea   25  1,85 m      87       79
# 193    P. Foden       CM     Man City   19  1,71 m      69       76
# 109   A. Tettey      CDM      Norwich   33  1,81 m      68       71
# 338    R. Saïss      CDM       Wolves   29  1,88 m      84       77
#
#      Potential  FIFAMarketValue  FIFAWage   Foot  WeakFoot  SkillMoves  \
# 281         81          8000000     41000  Right         4           3
# 333         82         16000000     98000  Right         5           4
# 193         90         16500000     52000   Left         3           4
# 109         71          1200000     25000  Right         2           2
# 338         77          7500000     68000   Left         3           3
#
#     BodyType  MainPositionStatus  MarketValue  YearBorn
# 281   Stocky                72.0     12000000      2001
# ...

# %% [markdown]
# ## Cut

# %%
pd.cut(df.FIFAMarketValue, bins=3)
# Out:
# 0         (60150.0, 30100000.0]
# 1         (60150.0, 30100000.0]
# 2         (60150.0, 30100000.0]
# 3         (60150.0, 30100000.0]
# 4         (60150.0, 30100000.0]
#                  ...
# 396       (60150.0, 30100000.0]
# 397       (60150.0, 30100000.0]
# 398    (30100000.0, 60050000.0]
# 399       (60150.0, 30100000.0]
# 400       (60150.0, 30100000.0]
# Name: FIFAMarketValue, Length: 401, dtype: category
# Categories (3, interval[float64, right]): [(60150.0, 30100000.0] < (30100000.0, 60050000.0] < (60050000.0, 90000000.0]]

# %%
pd.cut(df.FIFAMarketValue, bins=3, labels=["A", "B", "C"])
# Out:
# 0      A
# 1      A
# 2      A
# 3      A
# 4      A
#       ..
# 396    A
# 397    A
# 398    B
# 399    A
# 400    A
# Name: FIFAMarketValue, Length: 401, dtype: category
# Categories (3, object): ['A' < 'B' < 'C']

# %%
df["ValueRank"] = pd.cut(df.FIFAMarketValue, bins=3, labels=["A", "B", "C"])

# %%
df
# Out:
#              Name Position        ClubName  Age  Height  Weight  Overall  \
# 0        M. Noble       CM        West Ham   32  1,80 m      76       76
# 1     R. Stearman       CB  Sheffield Utd.   32  1,91 m      76       69
# 2       G. Hanley       CB         Norwich   27  1,88 m      81       70
# 3     P. Jagielka       CB  Sheffield Utd.   37  1,80 m      87       76
# 4     A. Townsend       RW  Crystal Palace   28  1,81 m      73       78
# ..            ...      ...             ...  ...     ...     ...      ...
# 396   V. Lindelöf       CB         Man Utd   25  1,87 m      80       81
# 397     O. Nyland       GK     Aston Villa   29  1,92 m      90       72
# 398     R. Mahrez       RW        Man City   28  1,79 m      67       84
# 399  S. Armstrong       CM     Southampton   27  1,83 m      75       75
# 400     E. Capoue      CDM         Watford   31  1,89 m      87       80
#
#      Potential  FIFAMarketValue  FIFAWage   Foot  WeakFoot  SkillMoves  \
# ...

# %%
# Left Wing and A Rank
df[ (df.Position == "LW") & (df.ValueRank == "A") ]
# Out:
#                Name Position        ClubName  Age  Height  Weight  Overall  \
# 24        D. McNeil       LW         Burnley   19  1,83 m      68       74
# 39          C. Atsu       LW       Newcastle   27  1,65 m      65       74
# 42      Richarlison       LW         Everton   22  1,79 m      71       79
# 152       Trezeguet       LW     Aston Villa   25  1,79 m      78       77
# 181  C. Hudson-Odoi       LW         Chelsea   19  1,77 m      75       74
# 194         Bernard       LW         Everton   27  1,64 m      60       80
# 216        D. James       LW         Man Utd   22  1,70 m      76       72
# 234       R. Holmes       LW  Sheffield Utd.   32  1,88 m      75       67
# 249      N. Redmond       LW     Southampton   25  1,73 m      69       77
# 264         B. Saka       LW         Arsenal   18  1,78 m      70       65
# 277      M. Djenepo       LW     Southampton   21  1,77 m      65       74
# ...
